# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# Composicion de pipelines
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Regresion lineal
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# Importar/ Exportar modelos
from joblib import dump, load

# Metricas
from sklearn.metrics import mean_squared_error as mse

# q-q plots
import scipy.stats as stats

# %%
# Importación de los datos, se exluyen desde el comienzo los NA-Value cono np.nan
data = pd.read_csv("Laboratorio 3.csv", na_values=["NA-VALUE"])
data.head()
# Out:
#    LeagueIndex   Age  HoursPerWeek  TotalHours       APM  SelectByHotkeys  \
# 0     6.429631  27.0          10.0      3000.0  143.7180         0.003515
# 1     6.034862  23.0          10.0      5000.0  129.2322         0.003304
# 2     5.000659  30.0          10.0       200.0   69.9612         0.001101
# 3     3.264122  19.0          20.0       400.0  107.6016         0.001034
# 4     3.883553  32.0          10.0       500.0  122.8908         0.001136
#
#    AssignToHotkeys  UniqueHotkeys  MinimapAttacks  MinimapRightClicks  \
# 0         0.000220            7.0        0.000110            0.000392
# 1         0.000259            4.0        0.000294            0.000432
# 2         0.000336            4.0        0.000294            0.000461
# 3         0.000213            1.0        0.000053            0.000543
# 4         0.000327            2.0        0.000000            0.001329
#
#    NumberOfPACs  GapBetweenPACs  ActionLatency  ActionsInPAC  \
# 0      0.004849         32.6677        40.8673        4.7508
# 1      0.004307         32.9194        42.3454        4.8434
# 2      0.002926         44.6475        75.3548        4.0430
# 3      0.003783         29.2203        53.7352        4.9155
# 4      0.002368         22.6885        62.0813        9.3740
#
#    TotalMapExplored  WorkersMade  UniqueUnitsMade  ComplexUnitsMade  \
# 0              28.0     0.001397              6.0               0.0
# 1              22.0     0.001193              5.0               0.0
# 2              22.0     0.000745              6.0               0.0
# 3              19.0     0.000426              7.0               0.0
# 4              15.0     0.001174              4.0               0.0
#
#    ComplexAbilitiesUsed
# 0              0.000000
# 1              0.000208
# 2              0.000189
# 3              0.000384
# 4              0.000019

# %%
data.describe()
# Out:
#        LeagueIndex          Age  HoursPerWeek      TotalHours          APM  \
# count  3238.000000  3237.000000   3237.000000     3237.000000  3237.000000
# mean      5.866763    21.664813     15.977757      974.513438   115.330177
# std       3.111672     4.234815     12.071767    17586.005507    48.394129
# min       0.000000    16.000000      0.000000        3.000000    22.059600
# 25%       4.123874    19.000000      8.000000      300.000000    80.002200
# 50%       5.680387    21.000000     12.000000      500.000000   108.002400
# 75%       7.082546    24.000000     20.000000      800.000000   141.628200
# max      20.000000    44.000000    168.000000  1000000.000000   389.831400
#
#        SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# count      3236.000000      3237.000000    3237.000000     3237.000000
# mean          0.004073         0.000367       4.342601        0.000095
# std           0.004759         0.000211       2.343168        0.000161
# min           0.000000         0.000000       0.000000        0.000000
# 25%           0.001257         0.000204       3.000000        0.000000
# 50%           0.002482         0.000352       4.000000        0.000040
# 75%           0.004987         0.000495       6.000000        0.000117
# max           0.043088         0.001648      10.000000        0.003019
#
#        MinimapRightClicks  NumberOfPACs  GapBetweenPACs  ActionLatency  \
# count         3236.000000   3238.000000     3236.000000    3237.000000
# mean             0.000385      0.003443       40.634541      64.052152
# std              0.000363      0.000971       17.144370      19.125397
# min              0.000000      0.000679        6.666700      24.632600
# 25%              0.000141      0.002751       29.214175      50.620700
# 50%              0.000282      0.003386       36.984250      61.124100
# 75%              0.000512      0.004017       48.446600      73.812500
# max              0.003688      0.007971      237.142900     176.372100
#
#        ActionsInPAC  TotalMapExplored  WorkersMade  UniqueUnitsMade  \
# count   3238.000000       3236.000000  3238.000000      3236.000000
# mean       5.277123         22.218789     0.001037         6.563968
# std        1.507255          7.465264     0.000525         1.862155
# min        2.038900          5.000000     0.000077         2.000000
# 25%        4.264100         17.000000     0.000685         5.000000
# 50%        5.093550         22.000000     0.000910         6.000000
# 75%        6.035900         27.000000     0.001268         8.000000
# max       18.558100         58.000000     0.005149        13.000000
#
#        ComplexUnitsMade  ComplexAbilitiesUsed
# count       3237.000000           3235.000000
# mean           0.000061              0.000144
# std            0.000113              0.000269
# min            0.000000              0.000000
# 25%            0.000000              0.000000
# 50%            0.000000              0.000021
# 75%            0.000090              0.000187
# max            0.000902              0.003084

# %%
plt.figure(figsize=(16, 10))
corr = data.corr()
sns.heatmap(corr, vmin=-1, vmax=1, cmap ="coolwarm",annot=True).set_title('Matriz de Correlación');

# %%
data = data.drop(columns = [ "ActionsInPAC", "ActionLatency", "GapBetweenPACs", "NumberOfPACs", "AssignToHotkeys", "SelectByHotkeys", "ComplexAbilitiesUsed", "UniqueUnitsMade"])

# %%
data.shape
# Out:
# (3238, 11)

# %%
sns.distplot(data["Age"]);

# %% [markdown]
# Quitamos los outliers de la columna HoursPerWeek. Consideramos que los datos mayores a 80 eran outliers.

# %%
sns.boxplot(data["HoursPerWeek"])
# Out:
# <AxesSubplot:xlabel='HoursPerWeek'>

# %%
data = data[data["HoursPerWeek"]<100]
sns.distplot(data["HoursPerWeek"])
data.shape
# Out:
# (3234, 11)

# %% [markdown]
# Quitamos los valores de TotalHours que podemos considerar outliers que son los mayores a 1000

# %%
sns.boxplot(data["TotalHours"])
# Out:
# <AxesSubplot:xlabel='TotalHours'>

# %%
data = data[data["TotalHours"]<4000]
data = data[data["TotalHours"]>0]
sns.distplot(data["TotalHours"])
data.shape
# Out:
# (3216, 11)

# %% [markdown]
# Borramos los valores mayores a 350 de acuerdo con el boxplot

# %%
sns.boxplot(data["APM"])
# Out:
# <AxesSubplot:xlabel='APM'>

# %%
data = data[data["APM"]<350]
sns.distplot(data["APM"])
data.shape
# Out:
# (3213, 11)

# %% [markdown]
# Borramos los valores que son menores a 0.02 de acuerdo con el boxplot

# %% [markdown]
# Borramos los valores que son outliers que corresponden a los mayores a 0.001

# %% [markdown]
# Dejamos esta variable como es ya que no tiene valores extremos radicales

# %%
sns.boxplot(data["UniqueHotkeys"])
# Out:
# <AxesSubplot:xlabel='UniqueHotkeys'>

# %%
sns.boxplot(data["MinimapAttacks"])
# Out:
# <AxesSubplot:xlabel='MinimapAttacks'>

# %%
data = data[data["MinimapAttacks"]<0.001]
sns.distplot(data["MinimapAttacks"])
data.shape
# Out:
# (3199, 11)

# %%
np.std(data["MinimapAttacks"])
# Out:
# 1.7003465788256692e-08

# %%
sns.boxplot(data["MinimapRightClicks"])
# Out:
# <AxesSubplot:xlabel='MinimapRightClicks'>

# %%
data = data[data["MinimapRightClicks"]<0.003]
sns.distplot(data["MinimapRightClicks"])
data.shape
# Out:
# (3195, 11)

# %%
sns.boxplot(data["TotalMapExplored"])
# Out:
# <AxesSubplot:xlabel='TotalMapExplored'>

# %%
sns.boxplot(data["WorkersMade"])
# Out:
# <AxesSubplot:xlabel='WorkersMade'>

# %%
data = data[data["WorkersMade"]<0.004]
sns.distplot(data["WorkersMade"])
data.shape
# Out:
# (3191, 11)

# %%
sns.boxplot(data["ComplexUnitsMade"])
# Out:
# <AxesSubplot:xlabel='ComplexUnitsMade'>

# %%
data = data[data["ComplexUnitsMade"]<0.0006]
sns.distplot(data["ComplexUnitsMade"])
data.shape
# Out:
# (3182, 11)

# %%
plt.figure(figsize=(16, 10))
corr = data.corr()
sns.heatmap(corr, vmin=-1, vmax=1, cmap ="coolwarm",annot=True).set_title('Matriz de Correlación');

# %%
data.isna().sum(axis=0)
data = data.dropna()
data = data.drop(columns = ["ComplexUnitsMade", "MinimapAttacks"])

# %%
y = data["LeagueIndex"]
X = data.drop(columns = "LeagueIndex")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
clf = linear_model.Lasso(alpha=0)
clf.fit(X_train, y_train)
# Out:
# Lasso(alpha=0)

# %%
clf.coef_
# Out:
# array([ 3.82506665e-03,  4.23977704e-03, -1.41871785e-06,  3.68030879e-03,
#         1.96137211e+01,  1.50557941e+03, -1.67016906e-03, -4.92155219e+00,
#         3.75259266e+02, -1.64187990e-02, -1.72798075e-02,  4.80881062e-02,
#        -9.97840428e-03,  2.82461063e+02,  2.93223467e-02, -1.65047336e+01])

# %%
adivinados = clf.predict(X_train)

# %%
print("MSE: %.2f" % mean_squared_error(y_train, adivinados, squared=False))
print("MAE: %.2f" % mean_absolute_error(y_train, adivinados))
print('R²: %.2f' % r2_score(y_train, adivinados))
# Out:
# MSE: 2.84
# MAE: 1.53
# R²: 0.18
